# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# ...

# %%
import datasets
from datasets import load_dataset
import pandas as pd
import numpy as np

ds = load_dataset("DataFog/medical-transcription-instruct")

df = ds['train'].to_pandas()

# %% [markdown]
# **Checking the missing values**

# %%
missingCount = df.isnull().sum()
cells = np.product(df.shape)
print("cells =",cells)
missing = missingCount.sum()
print("missing =",missing)
# Out:
# cells = 350316
# missing = 0

# %% [markdown]
# **Data preprocessing section**

# %%
class datapreprocessing:
  def clean(data):
    data = data.dropna(axis=1)
    return data

  def split_Extraction (data):
    feature = data["train"]["transcription"]
    labels = data["train"]["sample_name"]
    return feature, labels

  def split_Data (data):
    X_train, X_test, y_train, y_test = train_test_split(feature, labels, test_size = 0.23, shuffle = True, random_state = 7)


    X_train_fin = np.asarray(X_train)
    y_train_fin = np.asarray(y_train)
    X_test_fin = np.asarray(X_test)
    y_test_fin = np.asarray(y_test)


    return X_train_fin, X_test_fin, y_train_fin, y_test_fin

# %%
df = datapreprocessing.clean(df)
df.head(10)
# Out:
#                                          instruction  \
# 0  Identify the medical specialty for this transc...
# 1               Summarize this medical transcription
# 2  Generate an appropriate sample name for this t...
# 3           Extract key medical terms from this text
# 4  Assess the complexity of this medical transcri...
# 5  Determine if this transcription is longer or s...
# 6  Suggest potential follow-up questions based on...
# 7  Extract original key medical terms from this text
# 8  Identify the medical specialty for this transc...
# 9               Summarize this medical transcription
#
#                                          task_output  \
# 0                               Allergy / Immunology
# 1   A 23-year-old white female presents with comp...
# 2                                 Allergic Rhinitis
# 3                          she, does, used, has, but
# 4                                               0.68
# 5                               Shorter than average
# ...
